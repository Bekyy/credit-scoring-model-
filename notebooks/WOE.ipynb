# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os, sys

os.getcwd()
rpath = os.path.abspath('../')
if rpath not in sys.path:
    sys.path.insert(0,rpath)

# %%
data_path = os.path.join(rpath,'data','processed_data.csv')
data = pd.read_csv(data_path)
data.head()
# Out:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0  CustomerId_4406          UGX          256  ProviderId_6  ProductId_10
# 1  CustomerId_4406          UGX          256  ProviderId_4   ProductId_6
# 2  CustomerId_4683          UGX          256  ProviderId_6   ProductId_1
# 3   CustomerId_988          UGX          256  ProviderId_1  ProductId_21
# 4   CustomerId_988          UGX          256  ProviderId_4   ProductId_6
#
#       ProductCategory  ... TransactionAmountStdDev        Date  dy month  \
# 0             airtime  ...             3042.294251  2018-11-15  15    11
# 1  financial_services  ...             3042.294251  2018-11-15  15    11
# 2             airtime  ...                0.000000  2018-11-15  15    11
# 3        utility_bill  ...            17169.241610  2018-11-15  15    11
# 4  financial_services  ...            17169.241610  2018-11-15  15    11
#
#    year  ProductCategory_Encoded  CurrencyCode_Encoded  ChannelId_Encoded  \
# 0  2018                        0                     0                  2
# 1  2018                        2                     0                  1
# 2  2018                        0                     0                  2
# 3  2018                        8                     0                  2
# 4  2018                        2                     0                  1
#
#    Amount_Normalized  Value_Normalized
# 0           0.092004          0.000101
# 1           0.091910          0.000002
# 2           0.091958          0.000050
# 3           0.093750          0.002206
# 4           0.091853          0.000065
#
# [5 rows x 29 columns]
